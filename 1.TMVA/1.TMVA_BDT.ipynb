# %% [markdown]
# ## Tutorial on using TMVA methods
#
# In this tutorial we will use the Boosted Decision Tree of the TMVA library, installed with ROOT, for a binary classification problem. A .root file with higgs signal and background events is used as input.
# First, we will import some usefull libraries:

# %%
from ROOT import TMVA, TFile, TTree, TCut
from subprocess import call
from os.path import isfile
# Out:
# Welcome to JupyROOT 6.14/04

# %% [markdown]
# Now, we will set up TMVA, specifying the output file and the analysis type of the TMVA factory

# %%
# Setup TMVA
TMVA.Tools.Instance()
TMVA.PyMethodBase.PyInitialize()

output = TFile.Open('TMVA.root', 'RECREATE')
factory = TMVA.Factory('TMVAClassification', output,
                       '!V:!Silent:Color:DrawProgressBar::AnalysisType=Classification')

# %% [markdown]
# We have to select the input root file. It has two trees, one for the signal events and one for the background. Each one contains the same variables. The necessary labels will be handled by TMVA when we specify the signal and background tree. Then, we chose the number of event we want to train our model.

# %%
data = TFile.Open('../data/higgs_small.root')
# data = TFile.Open('../data/higgs.root')
signal = data.Get('TreeS')
background = data.Get('TreeB')

dataloader = TMVA.DataLoader('dataset')
for branch in signal.GetListOfBranches():
    dataloader.AddVariable(branch.GetName())

dataloader.AddSignalTree(signal, 1.0)
dataloader.AddBackgroundTree(background, 1.0)
dataloader.PrepareTrainingAndTestTree(TCut(''),
                                      'nTrain_Signal=3000:nTrain_Background=2500:SplitMode=Random:NormMode=NumEvents:!V')
# Out:
# DataSetInfo              : [dataset] : Added class "Signal"
#                          : Add Tree TreeS of type Signal with 5296 events
# DataSetInfo              : [dataset] : Added class "Background"
#                          : Add Tree TreeB of type Background with 4703 events
#                          : Dataset[dataset] : Class index : 0  name : Signal
#                          : Dataset[dataset] : Class index : 1  name : Background

# %% [markdown]
# ---
# Next step is choosing the built in method we want to use. We will use a BDT with 80 estimators, each one with a max depth of 4. With the `VarTransform` option we call aply transformations on the input variables. Here, we're using the decorrelation (`D`) and the gaussianization (`G`) options. Other options are normalisation,principal component analysis (PCA) and uniformisation with short-hand versions of (`N`,`P`,`U`)

# %%
factory.BookMethod(dataloader, TMVA.Types.kFisher, 'Fisher',
                   '!H:!V:Fisher:VarTransform=G,D')

factory.BookMethod(dataloader, TMVA.Types.kBDT, 'BDT',
                   '!H:!V:VarTransform=G,D:NTrees=800:MaxDepth=3:nCuts=20')
# Out:
# <ROOT.TMVA::MethodBDT object ("BDT") at 0x555e3dd88640>
# Factory                  : Booking method: Fisher
#                          :
# Fisher                   : [dataset] : Create Transformation "G" with events from all classes.
#                          :
#                          : Transformation, Variable selection :
#                          : Input : variable 'lepton_pT' <---> Output : variable 'lepton_pT'
#                          : Input : variable 'lepton_eta' <---> Output : variable 'lepton_eta'
#                          : Input : variable 'lepton_phi' <---> Output : variable 'lepton_phi'
#                          : Input : variable 'missing_energy_magnitude' <---> Output : variable 'missing_energy_magnitude'
#                          : Input : variable 'missing_energy_phi' <---> Output : variable 'missing_energy_phi'
#                          : Input : variable 'jet_1_pt' <---> Output : variable 'jet_1_pt'
#                          : Input : variable 'jet_1_eta' <---> Output : variable 'jet_1_eta'
#                          : Input : variable 'jet_1_phi' <---> Output : variable 'jet_1_phi'
#                          : Input : variable 'jet_1_b_tag' <---> Output : variable 'jet_1_b_tag'
#                          : Input : variable 'jet_2_pt' <---> Output : variable 'jet_2_pt'
#                          : Input : variable 'jet_2_eta' <---> Output : variable 'jet_2_eta'
#                          : Input : variable 'jet_2_phi' <---> Output : variable 'jet_2_phi'
#                          : Input : variable 'jet_2_b_tag' <---> Output : variable 'jet_2_b_tag'
#                          : Input : variable 'jet_3_pt' <---> Output : variable 'jet_3_pt'
#                          : Input : variable 'jet_3_eta' <---> Output : variable 'jet_3_eta'
#                          : Input : variable 'jet_3_phi' <---> Output : variable 'jet_3_phi'
#                          : Input : variable 'jet_3_b_tag' <---> Output : variable 'jet_3_b_tag'
#                          : Input : variable 'jet_4_pt' <---> Output : variable 'jet_4_pt'
#                          : Input : variable 'jet_4_eta' <---> Output : variable 'jet_4_eta'
#                          : Input : variable 'jet_4_phi' <---> Output : variable 'jet_4_phi'
#                          : Input : variable 'jet_4_b_tag' <---> Output : variable 'jet_4_b_tag'
#                          : Input : variable 'm_jj' <---> Output : variable 'm_jj'
#                          : Input : variable 'm_jjj' <---> Output : variable 'm_jjj'
#                          : Input : variable 'm_lv' <---> Output : variable 'm_lv'
#                          : Input : variable 'm_jlv' <---> Output : variable 'm_jlv'
#                          : Input : variable 'm_bb' <---> Output : variable 'm_bb'
#                          : Input : variable 'm_wbb' <---> Output : variable 'm_wbb'
#                          : Input : variable 'm_wwbb' <---> Output : variable 'm_wwbb'
# Fisher                   : [dataset] : Create Transformation "D" with events from all classes.
#                          :
#                          : Transformation, Variable selection :
#                          : Input : variable 'lepton_pT' <---> Output : variable 'lepton_pT'
#                          : Input : variable 'lepton_eta' <---> Output : variable 'lepton_eta'
#                          : Input : variable 'lepton_phi' <---> Output : variable 'lepton_phi'
#                          : Input : variable 'missing_energy_magnitude' <---> Output : variable 'missing_energy_magnitude'
#                          : Input : variable 'missing_energy_phi' <---> Output : variable 'missing_energy_phi'
#                          : Input : variable 'jet_1_pt' <---> Output : variable 'jet_1_pt'
#                          : Input : variable 'jet_1_eta' <---> Output : variable 'jet_1_eta'
#                          : Input : variable 'jet_1_phi' <---> Output : variable 'jet_1_phi'
#                          : Input : variable 'jet_1_b_tag' <---> Output : variable 'jet_1_b_tag'
#                          : Input : variable 'jet_2_pt' <---> Output : variable 'jet_2_pt'
#                          : Input : variable 'jet_2_eta' <---> Output : variable 'jet_2_eta'
#                          : Input : variable 'jet_2_phi' <---> Output : variable 'jet_2_phi'
#                          : Input : variable 'jet_2_b_tag' <---> Output : variable 'jet_2_b_tag'
#                          : Input : variable 'jet_3_pt' <---> Output : variable 'jet_3_pt'
#                          : Input : variable 'jet_3_eta' <---> Output : variable 'jet_3_eta'
#                          : Input : variable 'jet_3_phi' <---> Output : variable 'jet_3_phi'
#                          : Input : variable 'jet_3_b_tag' <---> Output : variable 'jet_3_b_tag'
#                          : Input : variable 'jet_4_pt' <---> Output : variable 'jet_4_pt'
#                          : Input : variable 'jet_4_eta' <---> Output : variable 'jet_4_eta'
#                          : Input : variable 'jet_4_phi' <---> Output : variable 'jet_4_phi'
#                          : Input : variable 'jet_4_b_tag' <---> Output : variable 'jet_4_b_tag'
#                          : Input : variable 'm_jj' <---> Output : variable 'm_jj'
#                          : Input : variable 'm_jjj' <---> Output : variable 'm_jjj'
#                          : Input : variable 'm_lv' <---> Output : variable 'm_lv'
#                          : Input : variable 'm_jlv' <---> Output : variable 'm_jlv'
#                          : Input : variable 'm_bb' <---> Output : variable 'm_bb'
#                          : Input : variable 'm_wbb' <---> Output : variable 'm_wbb'
#                          : Input : variable 'm_wwbb' <---> Output : variable 'm_wwbb'
# Factory                  : Booking method: BDT
#                          :
# BDT                      : [dataset] : Create Transformation "G" with events from all classes.
#                          :
#                          : Transformation, Variable selection :
#                          : Input : variable 'lepton_pT' <---> Output : variable 'lepton_pT'
#                          : Input : variable 'lepton_eta' <---> Output : variable 'lepton_eta'
#                          : Input : variable 'lepton_phi' <---> Output : variable 'lepton_phi'
#                          : Input : variable 'missing_energy_magnitude' <---> Output : variable 'missing_energy_magnitude'
#                          : Input : variable 'missing_energy_phi' <---> Output : variable 'missing_energy_phi'
#                          : Input : variable 'jet_1_pt' <---> Output : variable 'jet_1_pt'
#                          : Input : variable 'jet_1_eta' <---> Output : variable 'jet_1_eta'
#                          : Input : variable 'jet_1_phi' <---> Output : variable 'jet_1_phi'
#                          : Input : variable 'jet_1_b_tag' <---> Output : variable 'jet_1_b_tag'
#                          : Input : variable 'jet_2_pt' <---> Output : variable 'jet_2_pt'
#                          : Input : variable 'jet_2_eta' <---> Output : variable 'jet_2_eta'
#                          : Input : variable 'jet_2_phi' <---> Output : variable 'jet_2_phi'
#                          : Input : variable 'jet_2_b_tag' <---> Output : variable 'jet_2_b_tag'
#                          : Input : variable 'jet_3_pt' <---> Output : variable 'jet_3_pt'
#                          : Input : variable 'jet_3_eta' <---> Output : variable 'jet_3_eta'
#                          : Input : variable 'jet_3_phi' <---> Output : variable 'jet_3_phi'
#                          : Input : variable 'jet_3_b_tag' <---> Output : variable 'jet_3_b_tag'
#                          : Input : variable 'jet_4_pt' <---> Output : variable 'jet_4_pt'
#                          : Input : variable 'jet_4_eta' <---> Output : variable 'jet_4_eta'
#                          : Input : variable 'jet_4_phi' <---> Output : variable 'jet_4_phi'
#                          : Input : variable 'jet_4_b_tag' <---> Output : variable 'jet_4_b_tag'
#                          : Input : variable 'm_jj' <---> Output : variable 'm_jj'
#                          : Input : variable 'm_jjj' <---> Output : variable 'm_jjj'
#                          : Input : variable 'm_lv' <---> Output : variable 'm_lv'
#                          : Input : variable 'm_jlv' <---> Output : variable 'm_jlv'
#                          : Input : variable 'm_bb' <---> Output : variable 'm_bb'
#                          : Input : variable 'm_wbb' <---> Output : variable 'm_wbb'
#                          : Input : variable 'm_wwbb' <---> Output : variable 'm_wwbb'
# BDT                      : [dataset] : Create Transformation "D" with events from all classes.
#                          :
#                          : Transformation, Variable selection :
#                          : Input : variable 'lepton_pT' <---> Output : variable 'lepton_pT'
#                          : Input : variable 'lepton_eta' <---> Output : variable 'lepton_eta'
#                          : Input : variable 'lepton_phi' <---> Output : variable 'lepton_phi'
#                          : Input : variable 'missing_energy_magnitude' <---> Output : variable 'missing_energy_magnitude'
#                          : Input : variable 'missing_energy_phi' <---> Output : variable 'missing_energy_phi'
#                          : Input : variable 'jet_1_pt' <---> Output : variable 'jet_1_pt'
#                          : Input : variable 'jet_1_eta' <---> Output : variable 'jet_1_eta'
#                          : Input : variable 'jet_1_phi' <---> Output : variable 'jet_1_phi'
#                          : Input : variable 'jet_1_b_tag' <---> Output : variable 'jet_1_b_tag'
#                          : Input : variable 'jet_2_pt' <---> Output : variable 'jet_2_pt'
#                          : Input : variable 'jet_2_eta' <---> Output : variable 'jet_2_eta'
#                          : Input : variable 'jet_2_phi' <---> Output : variable 'jet_2_phi'
#                          : Input : variable 'jet_2_b_tag' <---> Output : variable 'jet_2_b_tag'
#                          : Input : variable 'jet_3_pt' <---> Output : variable 'jet_3_pt'
#                          : Input : variable 'jet_3_eta' <---> Output : variable 'jet_3_eta'
#                          : Input : variable 'jet_3_phi' <---> Output : variable 'jet_3_phi'
#                          : Input : variable 'jet_3_b_tag' <---> Output : variable 'jet_3_b_tag'
#                          : Input : variable 'jet_4_pt' <---> Output : variable 'jet_4_pt'
#                          : Input : variable 'jet_4_eta' <---> Output : variable 'jet_4_eta'
#                          : Input : variable 'jet_4_phi' <---> Output : variable 'jet_4_phi'
#                          : Input : variable 'jet_4_b_tag' <---> Output : variable 'jet_4_b_tag'
#                          : Input : variable 'm_jj' <---> Output : variable 'm_jj'
#                          : Input : variable 'm_jjj' <---> Output : variable 'm_jjj'
#                          : Input : variable 'm_lv' <---> Output : variable 'm_lv'
#                          : Input : variable 'm_jlv' <---> Output : variable 'm_jlv'
#                          : Input : variable 'm_bb' <---> Output : variable 'm_bb'
#                          : Input : variable 'm_wbb' <---> Output : variable 'm_wbb'
#                          : Input : variable 'm_wwbb' <---> Output : variable 'm_wwbb'
# DataSetFactory           : [dataset] : Number of events in input trees
#                          :
#                          :
#                          : Number of training and testing events
#                          : ---------------------------------------------------------------------------
#                          : Signal     -- training events            : 3000
#                          : Signal     -- testing events             : 2296
#                          : Signal     -- training and testing events: 5296
#                          : Background -- training events            : 2500
#                          : Background -- testing events             : 2203
#                          : Background -- training and testing events: 4703
#                          :
# DataSetInfo              : Correlation matrix (Signal):
#                          : ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#                          :                           lepton_pT lepton_eta lepton_phi missing_energy_magnitude missing_energy_phi jet_1_pt jet_1_eta jet_1_phi jet_1_b_tag jet_2_pt jet_2_eta jet_2_phi jet_2_b_tag jet_3_pt jet_3_eta jet_3_phi jet_3_b_tag jet_4_pt jet_4_eta jet_4_phi jet_4_b_tag    m_jj   m_jjj    m_lv   m_jlv    m_bb   m_wbb  m_wwbb
#                          :                lepton_pT:    +1.000     +0.013     -0.026                   -0.155             -0.015   +0.097    -0.005    +0.000      +0.032   -0.057    -0.024    +0.003      -0.002   -0.033    -0.002    -0.012      +0.045   -0.051    +0.008    -0.021      -0.036  +0.047  +0.038  +0.250  +0.061  -0.053  +0.044  +0.076
#                          :               lepton_eta:    +0.013     +1.000     +0.015                   -0.022             -0.003   -0.008    +0.292    -0.015      -0.008   -0.002    +0.299    -0.028      +0.000   +0.007    +0.245    +0.058      -0.003   -0.014    +0.223    -0.010      +0.012  +0.005  +0.010  +0.016  -0.009  -0.008  -0.004  -0.005
#                          :               lepton_phi:    -0.026     +0.015     +1.000                   -0.003             -0.072   -0.002    +0.002    -0.158      -0.008   +0.015    +0.014    -0.042      +0.003   +0.023    +0.018    -0.067      +0.004   -0.010    +0.006    -0.051      -0.001  +0.024  +0.038  -0.037  -0.032  +0.018  +0.006  +0.002
#                          : missing_energy_magnitude:    -0.155     -0.022     -0.003                   +1.000             +0.031   +0.137    +0.008    +0.023      +0.003   +0.004    +0.020    -0.009      -0.027   -0.017    -0.006    -0.002      -0.001   -0.017    +0.019    -0.000      -0.016  +0.045  +0.025  +0.253  +0.234  -0.019  +0.165  +0.229
#                          :       missing_energy_phi:    -0.015     -0.003     -0.072                   +0.031             +1.000   -0.009    +0.016    -0.148      -0.015   +0.003    -0.008    -0.054      +0.016   -0.004    -0.007    -0.012      -0.006   +0.008    -0.016    -0.009      -0.005  -0.001  -0.012  +0.011  -0.026  -0.007  -0.006  -0.020
#                          :                 jet_1_pt:    +0.097     -0.008     -0.002                   +0.137             -0.009   +1.000    -0.007    +0.010      -0.085   +0.489    +0.009    -0.013      -0.048   +0.278    -0.032    -0.024      +0.008   +0.166    -0.011    +0.008      +0.020  +0.209  +0.273  +0.023  +0.228  +0.228  +0.413  +0.414
#                          :                jet_1_eta:    -0.005     +0.292     +0.002                   +0.008             +0.016   -0.007    +1.000    -0.009      -0.010   +0.007    +0.225    +0.016      -0.003   -0.003    +0.220    +0.019      +0.017   +0.005    +0.150    -0.021      +0.007  +0.069  +0.073  +0.016  -0.004  -0.006  +0.037  +0.046
#                          :                jet_1_phi:    +0.000     -0.015     -0.158                   +0.023             -0.148   +0.010    -0.009    +1.000      -0.005   +0.004    -0.010    -0.227      -0.003   -0.033    +0.005    -0.149      +0.001   -0.026    +0.011    -0.165      -0.009  -0.003  -0.022  +0.024  +0.013  +0.002  -0.008  -0.004
#                          :              jet_1_b_tag:    +0.032     -0.008     -0.008                   +0.003             -0.015   -0.085    -0.010    -0.005      +1.000   -0.219    -0.012    +0.024      -0.296   -0.211    -0.022    -0.001      -0.219   -0.179    -0.003    +0.009      -0.201  -0.154  -0.101  +0.014  +0.098  +0.255  +0.041  -0.036
#                          :                 jet_2_pt:    -0.057     -0.002     +0.015                   +0.004             +0.003   +0.489    +0.007    +0.004      -0.219   +1.000    +0.020    -0.015      +0.150   +0.278    +0.003    +0.001      -0.044   +0.182    +0.028    +0.006      +0.007  +0.180  +0.237  +0.000  +0.206  +0.249  +0.383  +0.364
#                          :                jet_2_eta:    -0.024     +0.299     +0.014                   +0.020             -0.008   +0.009    +0.225    -0.010      -0.012   +0.020    +1.000    -0.030      -0.009   +0.007    +0.226    +0.037      +0.002   +0.030    +0.184    -0.015      -0.001  -0.012  +0.012  +0.002  +0.002  +0.006  +0.020  +0.024
#                          :                jet_2_phi:    +0.003     -0.028     -0.042                   -0.009             -0.054   -0.013    +0.016    -0.227      +0.024   -0.015    -0.030    +1.000      -0.001   -0.024    -0.010    -0.072      +0.006   +0.009    -0.013    -0.060      -0.005  -0.005  +0.006  -0.002  -0.008  +0.016  -0.006  -0.003
#                          :              jet_2_b_tag:    -0.002     +0.000     +0.003                   -0.027             +0.016   -0.048    -0.003    -0.003      -0.296   +0.150    -0.009    -0.001      +1.000   -0.062    +0.007    +0.018      -0.231   -0.059    +0.000    -0.004      -0.221  +0.022  +0.072  -0.021  +0.080  +0.125  +0.090  +0.064
#                          :                 jet_3_pt:    -0.033     +0.007     +0.023                   -0.017             -0.004   +0.278    -0.003    -0.033      -0.211   +0.278    +0.007    -0.024      -0.062   +1.000    -0.011    -0.004      +0.174   +0.278    +0.018    +0.010      -0.011  +0.143  +0.225  -0.011  +0.124  +0.196  +0.238  +0.247
#                          :                jet_3_eta:    -0.002     +0.245     +0.018                   -0.006             -0.007   -0.032    +0.220    +0.005      -0.022   +0.003    +0.226    -0.010      +0.007   -0.011    +1.000    -0.015      -0.025   +0.014    +0.158    +0.009      +0.007  -0.041  -0.027  +0.002  -0.001  -0.008  -0.012  -0.003
#                          :                jet_3_phi:    -0.012     +0.058     -0.067                   -0.002             -0.012   -0.024    +0.019    -0.149      -0.001   +0.001    +0.037    -0.072      +0.018   -0.004    -0.015    +1.000      -0.044   -0.000    +0.018    -0.081      +0.030  +0.016  +0.012  -0.009  -0.024  +0.006  -0.010  -0.007
#                          :              jet_3_b_tag:    +0.045     -0.003     +0.004                   -0.001             -0.006   +0.008    +0.017    +0.001      -0.219   -0.044    +0.002    +0.006      -0.231   +0.174    -0.025    -0.044      +1.000   -0.071    +0.006    +0.006      -0.289  +0.069  +0.070  +0.014  +0.010  -0.021  +0.019  +0.037
#                          :                 jet_4_pt:    -0.051     -0.014     -0.010                   -0.017             +0.008   +0.166    +0.005    -0.026      -0.179   +0.182    +0.030    +0.009      -0.059   +0.278    +0.014    -0.000      -0.071   +1.000    +0.006    +0.011      +0.186  +0.086  +0.185  -0.013  +0.066  +0.137  +0.160  +0.165
#                          :                jet_4_eta:    +0.008     +0.223     +0.006                   +0.019             -0.016   -0.011    +0.150    +0.011      -0.003   +0.028    +0.184    -0.013      +0.000   +0.018    +0.158    +0.018      +0.006   +0.006    +1.000    +0.017      +0.003  -0.025  -0.007  -0.012  +0.010  -0.025  -0.013  -0.004
#                          :                jet_4_phi:    -0.021     -0.010     -0.051                   -0.000             -0.009   +0.008    -0.021    -0.165      +0.009   +0.006    -0.015    -0.060      -0.004   +0.010    +0.009    -0.081      +0.006   +0.011    +0.017    +1.000      -0.010  +0.007  +0.014  +0.022  +0.015  +0.030  +0.023  +0.023
#                          :              jet_4_b_tag:    -0.036     +0.012     -0.001                   -0.016             -0.005   +0.020    +0.007    -0.009      -0.201   +0.007    -0.001    -0.005      -0.221   -0.011    +0.007    +0.030      -0.289   +0.186    +0.003    -0.010      +1.000  +0.112  +0.045  +0.004  -0.081  -0.169  -0.032  +0.002
#                          :                     m_jj:    +0.047     +0.005     +0.024                   +0.045             -0.001   +0.209    +0.069    -0.003      -0.154   +0.180    -0.012    -0.005      +0.022   +0.143    -0.041    +0.016      +0.069   +0.086    -0.025    +0.007      +0.112  +1.000  +0.766  +0.037  +0.119  +0.020  +0.524  +0.542
#                          :                    m_jjj:    +0.038     +0.010     +0.038                   +0.025             -0.012   +0.273    +0.073    -0.022      -0.101   +0.237    +0.012    +0.006      +0.072   +0.225    -0.027    +0.012      +0.070   +0.185    -0.007    +0.014      +0.045  +0.766  +1.000  +0.016  +0.100  +0.146  +0.683  +0.669
#                          :                     m_lv:    +0.250     +0.016     -0.037                   +0.253             +0.011   +0.023    +0.016    +0.024      +0.014   +0.000    +0.002    -0.002      -0.021   -0.011    +0.002    -0.009      +0.014   -0.013    -0.012    +0.022      +0.004  +0.037  +0.016  +1.000  +0.126  -0.034  +0.025  +0.054
#                          :                    m_jlv:    +0.061     -0.009     -0.032                   +0.234             -0.026   +0.228    -0.004    +0.013      +0.098   +0.206    +0.002    -0.008      +0.080   +0.124    -0.001    -0.024      +0.010   +0.066    +0.010    +0.015      -0.081  +0.119  +0.100  +0.126  +1.000  +0.343  +0.558  +0.580
#                          :                     m_bb:    -0.053     -0.008     +0.018                   -0.019             -0.007   +0.228    -0.006    +0.002      +0.255   +0.249    +0.006    +0.016      +0.125   +0.196    -0.008    +0.006      -0.021   +0.137    -0.025    +0.030      -0.169  +0.020  +0.146  -0.034  +0.343  +1.000  +0.461  +0.355
#                          :                    m_wbb:    +0.044     -0.004     +0.006                   +0.165             -0.006   +0.413    +0.037    -0.008      +0.041   +0.383    +0.020    -0.006      +0.090   +0.238    -0.012    -0.010      +0.019   +0.160    -0.013    +0.023      -0.032  +0.524  +0.683  +0.025  +0.558  +0.461  +1.000  +0.920
#                          :                   m_wwbb:    +0.076     -0.005     +0.002                   +0.229             -0.020   +0.414    +0.046    -0.004      -0.036   +0.364    +0.024    -0.003      +0.064   +0.247    -0.003    -0.007      +0.037   +0.165    -0.004    +0.023      +0.002  +0.542  +0.669  +0.054  +0.580  +0.355  +0.920  +1.000
#                          : ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# DataSetInfo              : Correlation matrix (Background):
#                          : ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#                          :                           lepton_pT lepton_eta lepton_phi missing_energy_magnitude missing_energy_phi jet_1_pt jet_1_eta jet_1_phi jet_1_b_tag jet_2_pt jet_2_eta jet_2_phi jet_2_b_tag jet_3_pt jet_3_eta jet_3_phi jet_3_b_tag jet_4_pt jet_4_eta jet_4_phi jet_4_b_tag    m_jj   m_jjj    m_lv   m_jlv    m_bb   m_wbb  m_wwbb
#                          :                lepton_pT:    +1.000     -0.020     +0.030                   -0.156             +0.002   +0.232    -0.004    -0.024      -0.037   +0.047    -0.004    -0.024      -0.021   +0.009    -0.037    -0.013      -0.001   -0.011    -0.016    +0.040      +0.063  +0.029  +0.028  +0.262  +0.105  -0.008  +0.102  +0.161
#                          :               lepton_eta:    -0.020     +1.000     -0.021                   -0.013             +0.011   -0.032    +0.250    -0.001      +0.016   -0.015    +0.244    +0.026      +0.003   +0.025    +0.191    -0.010      -0.024   -0.028    +0.116    +0.014      -0.004  +0.021  +0.021  -0.022  -0.003  -0.004  -0.003  -0.001
#                          :               lepton_phi:    +0.030     -0.021     +1.000                   -0.026             -0.025   -0.010    +0.036    -0.187      -0.011   -0.003    +0.002    -0.120      +0.000   -0.006    -0.001    -0.084      +0.032   -0.003    +0.009    -0.095      -0.033  +0.040  +0.032  +0.001  +0.016  -0.002  -0.006  +0.010
#                          : missing_energy_magnitude:    -0.156     -0.013     -0.026                   +1.000             -0.025   +0.299    -0.020    +0.004      -0.013   +0.070    +0.014    +0.016      -0.034   +0.054    +0.003    +0.000      +0.001   +0.088    +0.021    -0.048      +0.030  +0.048  +0.061  +0.117  +0.356  +0.090  +0.278  +0.366
#                          :       missing_energy_phi:    +0.002     +0.011     -0.025                   -0.025             +1.000   +0.006    -0.032    -0.157      +0.012   -0.001    +0.011    -0.106      -0.006   -0.019    -0.016    -0.068      -0.017   -0.020    -0.032    -0.068      +0.008  -0.006  +0.013  -0.008  -0.015  +0.026  +0.020  +0.006
#                          :                 jet_1_pt:    +0.232     -0.032     -0.010                   +0.299             +0.006   +1.000    -0.017    -0.032      +0.066   +0.476    -0.018    -0.008      -0.021   +0.262    -0.014    -0.001      -0.058   +0.115    -0.017    -0.015      -0.011  +0.157  +0.250  +0.003  +0.383  +0.480  +0.563  +0.515
#                          :                jet_1_eta:    -0.004     +0.250     +0.036                   -0.020             -0.032   -0.017    +1.000    -0.027      +0.003   -0.011    +0.267    +0.004      -0.015   +0.021    +0.220    +0.004      -0.004   +0.011    +0.191    +0.020      -0.043  -0.070  -0.043  -0.004  +0.016  +0.008  -0.018  -0.017
#                          :                jet_1_phi:    -0.024     -0.001     -0.187                   +0.004             -0.157   -0.032    -0.027    +1.000      -0.013   +0.002    -0.021    -0.173      +0.051   -0.012    -0.016    -0.141      -0.017   -0.018    -0.001    -0.070      -0.002  +0.008  -0.001  +0.008  -0.017  -0.001  -0.013  -0.013
#                          :              jet_1_b_tag:    -0.037     +0.016     -0.011                   -0.013             +0.012   +0.066    +0.003    -0.013      +1.000   -0.026    +0.003    -0.026      -0.226   -0.093    +0.016    +0.042      -0.257   -0.104    -0.038    +0.026      -0.277  -0.118  -0.039  +0.002  +0.169  +0.321  +0.166  +0.046
#                          :                 jet_2_pt:    +0.047     -0.015     -0.003                   +0.070             -0.001   +0.476    -0.011    +0.002      -0.026   +1.000    -0.012    +0.008      +0.147   +0.257    +0.023    -0.010      -0.084   +0.133    -0.025    +0.000      -0.061  +0.194  +0.253  +0.005  +0.261  +0.463  +0.474  +0.399
#                          :                jet_2_eta:    -0.004     +0.244     +0.002                   +0.014             +0.011   -0.018    +0.267    -0.021      +0.003   -0.012    +1.000    +0.017      +0.010   +0.021    +0.233    -0.008      -0.001   -0.028    +0.188    -0.008      -0.019  +0.002  +0.003  -0.023  +0.013  +0.023  -0.003  +0.011
#                          :                jet_2_phi:    -0.024     +0.026     -0.120                   +0.016             -0.106   -0.008    +0.004    -0.173      -0.026   +0.008    +0.017    +1.000      +0.004   +0.006    +0.011    -0.069      +0.010   -0.020    +0.013    -0.041      -0.006  -0.022  -0.030  +0.023  +0.006  -0.002  -0.023  -0.024
#                          :              jet_2_b_tag:    -0.021     +0.003     +0.000                   -0.034             -0.006   -0.021    -0.015    +0.051      -0.226   +0.147    +0.010    +0.004      +1.000   -0.110    +0.013    -0.048      -0.314   -0.120    -0.001    -0.016      -0.247  -0.008  +0.009  -0.003  +0.031  +0.140  +0.057  +0.002
#                          :                 jet_3_pt:    +0.009     +0.025     -0.006                   +0.054             -0.019   +0.262    +0.021    -0.012      -0.093   +0.257    +0.021    +0.006      -0.110   +1.000    -0.020    +0.006      +0.201   +0.255    +0.014    -0.015      -0.068  +0.138  +0.223  -0.013  +0.158  +0.323  +0.294  +0.279
#                          :                jet_3_eta:    -0.037     +0.191     -0.001                   +0.003             -0.016   -0.014    +0.220    -0.016      +0.016   +0.023    +0.233    +0.011      +0.013   -0.020    +1.000    -0.011      -0.038   -0.005    +0.145    -0.005      +0.001  +0.032  +0.040  -0.034  +0.018  +0.016  +0.045  +0.049
#                          :                jet_3_phi:    -0.013     -0.010     -0.084                   +0.000             -0.068   -0.001    +0.004    -0.141      +0.042   -0.010    -0.008    -0.069      -0.048   +0.006    -0.011    +1.000      +0.009   +0.000    -0.034    -0.078      +0.018  +0.018  +0.019  -0.005  +0.013  +0.013  +0.015  +0.006
#                          :              jet_3_b_tag:    -0.001     -0.024     +0.032                   +0.001             -0.017   -0.058    -0.004    -0.017      -0.257   -0.084    -0.001    +0.010      -0.314   +0.201    -0.038    +0.009      +1.000   -0.052    -0.014    +0.004      -0.235  +0.046  +0.028  +0.005  -0.053  -0.098  -0.075  -0.025
#                          :                 jet_4_pt:    -0.011     -0.028     -0.003                   +0.088             -0.020   +0.115    +0.011    -0.018      -0.104   +0.133    -0.028    -0.020      -0.120   +0.255    -0.005    +0.000      -0.052   +1.000    +0.022    -0.013      +0.205  +0.090  +0.151  +0.017  +0.091  +0.134  +0.164  +0.175
#                          :                jet_4_eta:    -0.016     +0.116     +0.009                   +0.021             -0.032   -0.017    +0.191    -0.001      -0.038   -0.025    +0.188    +0.013      -0.001   +0.014    +0.145    -0.034      -0.014   +0.022    +1.000    -0.021      -0.006  -0.019  -0.030  -0.017  -0.012  -0.028  -0.026  -0.021
#                          :                jet_4_phi:    +0.040     +0.014     -0.095                   -0.048             -0.068   -0.015    +0.020    -0.070      +0.026   +0.000    -0.008    -0.041      -0.016   -0.015    -0.005    -0.078      +0.004   -0.013    -0.021    +1.000      +0.006  +0.007  +0.002  -0.008  -0.011  -0.027  -0.019  -0.034
#                          :              jet_4_b_tag:    +0.063     -0.004     -0.033                   +0.030             +0.008   -0.011    -0.043    -0.002      -0.277   -0.061    -0.019    -0.006      -0.247   -0.068    +0.001    +0.018      -0.235   +0.205    -0.006    +0.006      +1.000  +0.120  +0.058  -0.007  -0.093  -0.222  -0.065  +0.023
#                          :                     m_jj:    +0.029     +0.021     +0.040                   +0.048             -0.006   +0.157    -0.070    +0.008      -0.118   +0.194    +0.002    -0.022      -0.008   +0.138    +0.032    +0.018      +0.046   +0.090    -0.019    +0.007      +0.120  +1.000  +0.819  -0.002  +0.130  +0.010  +0.388  +0.392
#                          :                    m_jjj:    +0.028     +0.021     +0.032                   +0.061             +0.013   +0.250    -0.043    -0.001      -0.039   +0.253    +0.003    -0.030      +0.009   +0.223    +0.040    +0.019      +0.028   +0.151    -0.030    +0.002      +0.058  +0.819  +1.000  -0.004  +0.171  +0.158  +0.538  +0.513
#                          :                     m_lv:    +0.262     -0.022     +0.001                   +0.117             -0.008   +0.003    -0.004    +0.008      +0.002   +0.005    -0.023    +0.023      -0.003   -0.013    -0.034    -0.005      +0.005   +0.017    -0.017    -0.008      -0.007  -0.002  -0.004  +1.000  +0.108  +0.002  +0.024  +0.030
#                          :                    m_jlv:    +0.105     -0.003     +0.016                   +0.356             -0.015   +0.383    +0.016    -0.017      +0.169   +0.261    +0.013    +0.006      +0.031   +0.158    +0.018    +0.013      -0.053   +0.091    -0.012    -0.011      -0.093  +0.130  +0.171  +0.108  +1.000  +0.347  +0.590  +0.533
#                          :                     m_bb:    -0.008     -0.004     -0.002                   +0.090             +0.026   +0.480    +0.008    -0.001      +0.321   +0.463    +0.023    -0.002      +0.140   +0.323    +0.016    +0.013      -0.098   +0.134    -0.028    -0.027      -0.222  +0.010  +0.158  +0.002  +0.347  +1.000  +0.623  +0.447
#                          :                    m_wbb:    +0.102     -0.003     -0.006                   +0.278             +0.020   +0.563    -0.018    -0.013      +0.166   +0.474    -0.003    -0.023      +0.057   +0.294    +0.045    +0.015      -0.075   +0.164    -0.026    -0.019      -0.065  +0.388  +0.538  +0.024  +0.590  +0.623  +1.000  +0.885
#                          :                   m_wwbb:    +0.161     -0.001     +0.010                   +0.366             +0.006   +0.515    -0.017    -0.013      +0.046   +0.399    +0.011    -0.024      +0.002   +0.279    +0.049    +0.006      -0.025   +0.175    -0.021    -0.034      +0.023  +0.392  +0.513  +0.030  +0.533  +0.447  +0.885  +1.000
#                          : ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# DataSetFactory           : [dataset] :
#                          :

# %%
# Run training, test and evaluation
factory.TrainAllMethods()
factory.TestAllMethods()
factory.EvaluateAllMethods()
# Out:
# Factory                  : Train all methods
# Factory                  : [dataset] : Create Transformation "I" with events from all classes.
#                          :
#                          : Transformation, Variable selection :
#                          : Input : variable 'lepton_pT' <---> Output : variable 'lepton_pT'
#                          : Input : variable 'lepton_eta' <---> Output : variable 'lepton_eta'
#                          : Input : variable 'lepton_phi' <---> Output : variable 'lepton_phi'
#                          : Input : variable 'missing_energy_magnitude' <---> Output : variable 'missing_energy_magnitude'
#                          : Input : variable 'missing_energy_phi' <---> Output : variable 'missing_energy_phi'
#                          : Input : variable 'jet_1_pt' <---> Output : variable 'jet_1_pt'
#                          : Input : variable 'jet_1_eta' <---> Output : variable 'jet_1_eta'
#                          : Input : variable 'jet_1_phi' <---> Output : variable 'jet_1_phi'
#                          : Input : variable 'jet_1_b_tag' <---> Output : variable 'jet_1_b_tag'
#                          : Input : variable 'jet_2_pt' <---> Output : variable 'jet_2_pt'
#                          : Input : variable 'jet_2_eta' <---> Output : variable 'jet_2_eta'
#                          : Input : variable 'jet_2_phi' <---> Output : variable 'jet_2_phi'
#                          : Input : variable 'jet_2_b_tag' <---> Output : variable 'jet_2_b_tag'
#                          : Input : variable 'jet_3_pt' <---> Output : variable 'jet_3_pt'
#                          : Input : variable 'jet_3_eta' <---> Output : variable 'jet_3_eta'
#                          : Input : variable 'jet_3_phi' <---> Output : variable 'jet_3_phi'
#                          : Input : variable 'jet_3_b_tag' <---> Output : variable 'jet_3_b_tag'
#                          : Input : variable 'jet_4_pt' <---> Output : variable 'jet_4_pt'
#                          : Input : variable 'jet_4_eta' <---> Output : variable 'jet_4_eta'
#                          : Input : variable 'jet_4_phi' <---> Output : variable 'jet_4_phi'
#                          : Input : variable 'jet_4_b_tag' <---> Output : variable 'jet_4_b_tag'
#                          : Input : variable 'm_jj' <---> Output : variable 'm_jj'
#                          : Input : variable 'm_jjj' <---> Output : variable 'm_jjj'
#                          : Input : variable 'm_lv' <---> Output : variable 'm_lv'
#                          : Input : variable 'm_jlv' <---> Output : variable 'm_jlv'
#                          : Input : variable 'm_bb' <---> Output : variable 'm_bb'
#                          : Input : variable 'm_wbb' <---> Output : variable 'm_wbb'
#                          : Input : variable 'm_wwbb' <---> Output : variable 'm_wwbb'
# TFHandler_Factory        :                 Variable                        Mean                        RMS                [        Min                        Max ]
#                          : -------------------------------------------------------------------------------------------------------------------------------------------
#                          :                lepton_pT:                    1.0019                   0.56827   [                   0.27598                    5.3305 ]
#                          :               lepton_eta:                 -0.031029                   0.99399   [                   -2.4165                    2.4271 ]
#                          :               lepton_phi:                -0.0013634                    1.0104   [                   -1.7420                    1.7432 ]
#                          : missing_energy_magnitude:                   0.98536                   0.59558   [                  0.022017                    5.8240 ]
#                          :       missing_energy_phi:                 0.0067296                    1.0064   [                   -1.7438                    1.7428 ]
#                          :                 jet_1_pt:                   0.99412                   0.47898   [                   0.15949                    7.0647 ]
#                          :                jet_1_eta:                 0.0082547                   0.98998   [                   -2.9133                    2.9697 ]
#                          :                jet_1_phi:                 -0.018524                    1.0191   [                   -1.7412                    1.7415 ]
#                          :              jet_1_b_tag:                    1.0204                    1.0306   [                    0.0000                    2.1731 ]
#                          :                 jet_2_pt:                   0.98896                   0.48817   [                   0.19100                    5.1925 ]
#                          :                jet_2_eta:                 -0.017887                   0.99392   [                   -2.8907                    2.9016 ]
#                          :                jet_2_phi:                  0.015022                    1.0048   [                   -1.7424                    1.7432 ]
#                          :              jet_2_b_tag:                   0.98582                    1.0470   [                    0.0000                    2.2149 ]
#                          :                 jet_3_pt:                   0.99538                   0.49273   [                   0.26413                    6.5233 ]
#                          :                jet_3_eta:                  0.011844                    1.0198   [                   -2.7260                    2.7273 ]
#                          :                jet_3_phi:                  0.010246                   0.99610   [                   -1.7415                    1.7407 ]
#                          :              jet_3_b_tag:                   0.99288                    1.1942   [                    0.0000                    2.5482 ]
#                          :                 jet_4_pt:                   0.97786                   0.49171   [                   0.36560                    4.2197 ]
#                          :                jet_4_eta:                -0.0022055                   0.99901   [                   -2.4948                    2.4955 ]
#                          :                jet_4_phi:                -0.0096314                    1.0085   [                   -1.7421                    1.7428 ]
#                          :              jet_4_b_tag:                    1.0042                    1.4013   [                    0.0000                    3.1020 ]
#                          :                     m_jj:                    1.0276                   0.63347   [                   0.18304                    10.180 ]
#                          :                    m_jjj:                    1.0223                   0.36844   [                   0.34247                    5.5198 ]
#                          :                     m_lv:                    1.0503                   0.16470   [                   0.55621                    3.0985 ]
#                          :                    m_jlv:                    1.0151                   0.40533   [                   0.41660                    5.8799 ]
#                          :                     m_bb:                   0.96717                   0.52128   [                  0.080986                    8.2551 ]
#                          :                    m_wbb:                    1.0313                   0.36481   [                   0.38878                    4.7495 ]
#                          :                   m_wwbb:                   0.95654                   0.31029   [                   0.47279                    4.0438 ]
#                          : -------------------------------------------------------------------------------------------------------------------------------------------
#                          :
#                          : <PlotVariables> Will not produce scatter plots ==>
#                          : |  The number of 28 input variables and 0 target values would require 378 two-dimensional
#                          : |  histograms, which would occupy the computer's memory. Note that this
#                          : |  suppression does not have any consequences for your analysis, other
#                          : |  than not disposing of these scatter plots. You can modify the maximum
#                          : |  number of input variables allowed to generate scatter plots in your
#                          : |  script via the command line:
#                          : |  "(TMVA::gConfig().GetVariablePlotting()).fMaxNumOfAllowedVariablesForScatterPlots = <some int>;"
#                          :
#                          : Some more output
#                          : Ranking input variables (method unspecific)...
# IdTransformation         : Ranking result (top variable is best ranked)
#                          : -------------------------------------------------
#                          : Rank : Variable                 : Separation
#                          : -------------------------------------------------
#                          :    1 : m_bb                     : 9.641e-02
#                          :    2 : m_wbb                    : 4.759e-02
#                          :    3 : m_wwbb                   : 3.977e-02
#                          :    4 : m_jjj                    : 2.931e-02
#                          :    5 : m_jlv                    : 1.855e-02
#                          :    6 : missing_energy_magnitude : 1.770e-02
#                          :    7 : jet_1_pt                 : 1.314e-02
#                          :    8 : jet_2_pt                 : 1.063e-02
#                          :    9 : lepton_pT                : 9.608e-03
#                          :   10 : jet_4_eta                : 8.750e-03
#                          :   11 : m_jj                     : 8.279e-03
#                          :   12 : jet_1_phi                : 8.094e-03
#                          :   13 : jet_4_pt                 : 8.083e-03
#                          :   14 : lepton_eta               : 8.036e-03
#                          :   15 : jet_2_phi                : 8.027e-03
#                          :   16 : jet_3_eta                : 7.682e-03
#                          :   17 : jet_2_eta                : 7.647e-03
#                          :   18 : jet_4_phi                : 7.365e-03
#                          :   19 : jet_3_phi                : 7.271e-03
#                          :   20 : jet_3_pt                 : 7.192e-03
#                          :   21 : m_lv                     : 6.634e-03
#                          :   22 : missing_energy_phi       : 5.733e-03
#                          :   23 : lepton_phi               : 5.140e-03
#                          :   24 : jet_1_eta                : 4.999e-03
#                          :   25 : jet_2_b_tag              : 3.413e-03
#                          :   26 : jet_3_b_tag              : 1.186e-03
#                          :   27 : jet_4_b_tag              : 1.029e-03
#                          :   28 : jet_1_b_tag              : 3.345e-04
#                          : -------------------------------------------------
# Factory                  : Train method: Fisher for Classification
#                          :
#                          : Preparing the Gaussian transformation...
#                          : Preparing the Decorrelation transformation...
# TFHandler_Fisher         :                 Variable                        Mean                        RMS                [        Min                        Max ]
#                          : -------------------------------------------------------------------------------------------------------------------------------------------
#                          :                lepton_pT:                -0.0060237                    1.0000   [                   -3.2653                    5.7066 ]
#                          :               lepton_eta:                 0.0046161                    1.0000   [                   -3.2329                    6.2269 ]
#                          :               lepton_phi:                  0.024490                    1.0000   [                   -3.0015                    5.8990 ]
#                          : missing_energy_magnitude:                  0.055273                    1.0000   [                   -3.2662                    6.1088 ]
#                          :       missing_energy_phi:                  0.025289                    1.0000   [                   -3.0116                    5.8455 ]
#                          :                 jet_1_pt:                   0.12914                    1.0000   [                   -3.1389                    4.2801 ]
#                          :                jet_1_eta:                  0.045926                    1.0000   [                   -3.2513                    6.6153 ]
#                          :                jet_1_phi:                  0.010970                    1.0000   [                   -3.0948                    6.2018 ]
#                          :              jet_1_b_tag:                    1.1094                    1.0000   [                  -0.51629                    2.7202 ]
#                          :                 jet_2_pt:                   0.11350                    1.0000   [                   -3.5335                    6.7224 ]
#                          :                jet_2_eta:                  0.018796                    1.0000   [                   -3.3604                    6.2055 ]
#                          :                jet_2_phi:                  0.013979                    1.0000   [                   -2.9690                    5.8830 ]
#                          :              jet_2_b_tag:                    1.0613                    1.0000   [                  -0.42941                    2.6591 ]
#                          :                 jet_3_pt:                   0.15221                    1.0000   [                   -3.4025                    6.4718 ]
#                          :                jet_3_eta:                  0.027633                    1.0000   [                   -3.1953                    5.9642 ]
#                          :                jet_3_phi:                  0.012035                    1.0000   [                   -3.0058                    5.7900 ]
#                          :              jet_3_b_tag:                   0.95873                    1.0000   [                  -0.45821                    2.5797 ]
#                          :                 jet_4_pt:                   0.16499                    1.0000   [                   -3.0953                    6.0059 ]
#                          :                jet_4_eta:                  0.022926                    1.0000   [                   -3.0541                    5.8535 ]
#                          :                jet_4_phi:                -0.0064017                    1.0000   [                   -3.0010                    5.7586 ]
#                          :              jet_4_b_tag:                   0.83778                    1.0000   [                  -0.55764                    2.6457 ]
#                          :                     m_jj:                  0.081964                    1.0000   [                   -3.7805                    4.7304 ]
#                          :                    m_jjj:                  -0.10118                    1.0000   [                   -3.3565                    4.9478 ]
#                          :                     m_lv:                  0.018596                    1.0000   [                   -3.3176                    5.5846 ]
#                          :                    m_jlv:                  -0.10590                    1.0000   [                   -3.9954                    4.6335 ]
#                          :                     m_bb:                  -0.27065                    1.0000   [                   -4.2380                    4.2014 ]
#                          :                    m_wbb:                  -0.10977                    1.0000   [                   -4.7328                    6.7603 ]
#                          :                   m_wwbb:                  0.015212                    1.0000   [                   -2.8921                    6.8370 ]
#                          : -------------------------------------------------------------------------------------------------------------------------------------------
# Fisher                   : Results for Fisher coefficients:
#                          : NOTE: The coefficients must be applied to TRANFORMED variables
#                          :   List of the transformation:
#                          :   -- Gauss
#                          :   -- Deco
#                          : ---------------------------------------------------
#                          :                 Variable:              Coefficient:
#                          : ---------------------------------------------------
#                          :                lepton_pT:                   -0.017
#                          :               lepton_eta:                   -0.015
#                          :               lepton_phi:                   +0.005
#                          : missing_energy_magnitude:                   -0.038
#                          :       missing_energy_phi:                   -0.005
#                          :                 jet_1_pt:                   +0.052
#                          :                jet_1_eta:                   +0.005
#                          :                jet_1_phi:                   +0.010
#                          :              jet_1_b_tag:                   -0.011
#                          :                 jet_2_pt:                   +0.015
#                          :                jet_2_eta:                   +0.020
#                          :                jet_2_phi:                   +0.000
#                          :              jet_2_b_tag:                   -0.023
#                          :                 jet_3_pt:                   +0.016
#                          :                jet_3_eta:                   +0.003
#                          :                jet_3_phi:                   +0.003
#                          :              jet_3_b_tag:                   -0.023
#                          :                 jet_4_pt:                   +0.027
#                          :                jet_4_eta:                   -0.000
#                          :                jet_4_phi:                   -0.001
#                          :              jet_4_b_tag:                   -0.000
#                          :                     m_jj:                   +0.013
#                          :                    m_jjj:                   +0.011
#                          :                     m_lv:                   +0.015
#                          :                    m_jlv:                   +0.010
#                          :                     m_bb:                   -0.059
#                          :                    m_wbb:                   +0.043
#                          :                   m_wwbb:                   -0.102
#                          :                 (offset):                   +0.040
#                          : ---------------------------------------------------
#                          : Elapsed time for training with 5500 events: 0.257 sec
# Fisher                   : [dataset] : Evaluation of Fisher on training sample (5500 events)
#                          : Elapsed time for evaluation of 5500 events: 0.0865 sec
#                          : Creating xml weight file: dataset/weights/TMVAClassification_Fisher.weights.xml
#                          : Creating standalone class: dataset/weights/TMVAClassification_Fisher.class.C
# Factory                  : Training finished
#                          :
# Factory                  : Train method: BDT for Classification
#                          :
#                          : Preparing the Gaussian transformation...
#                          : Preparing the Decorrelation transformation...
# TFHandler_BDT            :                 Variable                        Mean                        RMS                [        Min                        Max ]
#                          : -------------------------------------------------------------------------------------------------------------------------------------------
#                          :                lepton_pT:                -0.0060237                    1.0000   [                   -3.2653                    5.7066 ]
#                          :               lepton_eta:                 0.0046161                    1.0000   [                   -3.2329                    6.2269 ]
#                          :               lepton_phi:                  0.024490                    1.0000   [                   -3.0015                    5.8990 ]
#                          : missing_energy_magnitude:                  0.055273                    1.0000   [                   -3.2662                    6.1088 ]
#                          :       missing_energy_phi:                  0.025289                    1.0000   [                   -3.0116                    5.8455 ]
#                          :                 jet_1_pt:                   0.12914                    1.0000   [                   -3.1389                    4.2801 ]
#                          :                jet_1_eta:                  0.045926                    1.0000   [                   -3.2513                    6.6153 ]
#                          :                jet_1_phi:                  0.010970                    1.0000   [                   -3.0948                    6.2018 ]
#                          :              jet_1_b_tag:                    1.1094                    1.0000   [                  -0.51629                    2.7202 ]
#                          :                 jet_2_pt:                   0.11350                    1.0000   [                   -3.5335                    6.7224 ]
#                          :                jet_2_eta:                  0.018796                    1.0000   [                   -3.3604                    6.2055 ]
#                          :                jet_2_phi:                  0.013979                    1.0000   [                   -2.9690                    5.8830 ]
#                          :              jet_2_b_tag:                    1.0613                    1.0000   [                  -0.42941                    2.6591 ]
#                          :                 jet_3_pt:                   0.15221                    1.0000   [                   -3.4025                    6.4718 ]
#                          :                jet_3_eta:                  0.027633                    1.0000   [                   -3.1953                    5.9642 ]
#                          :                jet_3_phi:                  0.012035                    1.0000   [                   -3.0058                    5.7900 ]
#                          :              jet_3_b_tag:                   0.95873                    1.0000   [                  -0.45821                    2.5797 ]
#                          :                 jet_4_pt:                   0.16499                    1.0000   [                   -3.0953                    6.0059 ]
#                          :                jet_4_eta:                  0.022926                    1.0000   [                   -3.0541                    5.8535 ]
#                          :                jet_4_phi:                -0.0064017                    1.0000   [                   -3.0010                    5.7586 ]
#                          :              jet_4_b_tag:                   0.83778                    1.0000   [                  -0.55764                    2.6457 ]
#                          :                     m_jj:                  0.081964                    1.0000   [                   -3.7805                    4.7304 ]
#                          :                    m_jjj:                  -0.10118                    1.0000   [                   -3.3565                    4.9478 ]
#                          :                     m_lv:                  0.018596                    1.0000   [                   -3.3176                    5.5846 ]
#                          :                    m_jlv:                  -0.10590                    1.0000   [                   -3.9954                    4.6335 ]
#                          :                     m_bb:                  -0.27065                    1.0000   [                   -4.2380                    4.2014 ]
#                          :                    m_wbb:                  -0.10977                    1.0000   [                   -4.7328                    6.7603 ]
#                          :                   m_wwbb:                  0.015212                    1.0000   [                   -2.8921                    6.8370 ]
#                          : -------------------------------------------------------------------------------------------------------------------------------------------
# BDT                      : #events: (reweighted) sig: 2750 bkg: 2750
#                          : #events: (unweighted) sig: 3000 bkg: 2500
#                          : Training 800 Decision Trees ... patience please
#                          : Elapsed time for training with 5500 events: 5.24 sec
# BDT                      : [dataset] : Evaluation of BDT on training sample (5500 events)
#                          : Elapsed time for evaluation of 5500 events: 0.68 sec
#                          : Creating xml weight file: dataset/weights/TMVAClassification_BDT.weights.xml
#                          : Creating standalone class: dataset/weights/TMVAClassification_BDT.class.C
#                          : TMVA.root:/dataset/Method_BDT/BDT
# Factory                  : Training finished
#                          :
#                          : Ranking input variables (method specific)...
# Fisher                   : Ranking result (top variable is best ranked)
#                          : ---------------------------------------------------
#                          : Rank : Variable                 : Discr. power
#                          : ---------------------------------------------------
#                          :    1 : m_wwbb                   : 1.840e-02
#                          :    2 : m_bb                     : 5.931e-03
#                          :    3 : jet_1_pt                 : 4.330e-03
#                          :    4 : m_wbb                    : 3.156e-03
#                          :    5 : missing_energy_magnitude : 2.500e-03
#                          :    6 : jet_4_pt                 : 1.174e-03
#                          :    7 : jet_2_b_tag              : 8.902e-04
#                          :    8 : jet_3_b_tag              : 8.730e-04
#                          :    9 : jet_2_eta                : 6.473e-04
#                          :   10 : lepton_pT                : 4.895e-04
#                          :   11 : jet_3_pt                 : 4.299e-04
#                          :   12 : lepton_eta               : 4.112e-04
#                          :   13 : m_lv                     : 3.742e-04
#                          :   14 : jet_2_pt                 : 3.598e-04
#                          :   15 : m_jj                     : 3.046e-04
#                          :   16 : m_jjj                    : 2.259e-04
#                          :   17 : m_jlv                    : 1.933e-04
#                          :   18 : jet_1_b_tag              : 1.933e-04
#                          :   19 : jet_1_phi                : 1.636e-04
#                          :   20 : jet_1_eta                : 5.215e-05
#                          :   21 : missing_energy_phi       : 4.552e-05
#                          :   22 : lepton_phi               : 3.916e-05
#                          :   23 : jet_3_phi                : 1.728e-05
#                          :   24 : jet_3_eta                : 1.698e-05
#                          :   25 : jet_4_phi                : 2.316e-06
#                          :   26 : jet_4_b_tag              : 3.966e-07
#                          :   27 : jet_2_phi                : 1.599e-07
#                          :   28 : jet_4_eta                : 2.219e-09
#                          : ---------------------------------------------------
# BDT                      : Ranking result (top variable is best ranked)
#                          : ----------------------------------------------------------
#                          : Rank : Variable                 : Variable Importance
#                          : ----------------------------------------------------------
#                          :    1 : m_bb                     : 5.113e-02
#                          :    2 : m_wwbb                   : 4.705e-02
#                          :    3 : m_jlv                    : 4.519e-02
#                          :    4 : lepton_pT                : 4.433e-02
#                          :    5 : jet_1_pt                 : 4.335e-02
#                          :    6 : m_wbb                    : 4.042e-02
#                          :    7 : jet_2_pt                 : 3.889e-02
#                          :    8 : m_jjj                    : 3.708e-02
#                          :    9 : m_jj                     : 3.671e-02
#                          :   10 : jet_3_phi                : 3.669e-02
#                          :   11 : jet_4_eta                : 3.643e-02
#                          :   12 : jet_4_phi                : 3.625e-02
#                          :   13 : jet_3_pt                 : 3.617e-02
#                          :   14 : jet_1_eta                : 3.586e-02
#                          :   15 : lepton_eta               : 3.575e-02
#                          :   16 : missing_energy_magnitude : 3.515e-02
#                          :   17 : m_lv                     : 3.343e-02
#                          :   18 : lepton_phi               : 3.334e-02
#                          :   19 : jet_3_eta                : 3.324e-02
#                          :   20 : jet_1_phi                : 3.295e-02
#                          :   21 : jet_2_phi                : 3.229e-02
#                          :   22 : jet_4_pt                 : 3.220e-02
#                          :   23 : jet_2_eta                : 3.087e-02
#                          :   24 : jet_1_b_tag              : 2.957e-02
#                          :   25 : missing_energy_phi       : 2.946e-02
#                          :   26 : jet_4_b_tag              : 2.609e-02
#                          :   27 : jet_3_b_tag              : 2.521e-02
#                          :   28 : jet_2_b_tag              : 2.492e-02
#                          : ----------------------------------------------------------
# Factory                  : === Destroy and recreate all methods via weight files for testing ===
#                          :
#                          : Reading weight file: dataset/weights/TMVAClassification_Fisher.weights.xml
#                          : Reading weight file: dataset/weights/TMVAClassification_BDT.weights.xml
# Factory                  : Test all methods
# Factory                  : Test method: Fisher for Classification performance
#                          :
# Fisher                   : [dataset] : Evaluation of Fisher on testing sample (4499 events)
#                          : Elapsed time for evaluation of 4499 events: 0.07 sec
# Factory                  : Test method: BDT for Classification performance
#                          :
# BDT                      : [dataset] : Evaluation of BDT on testing sample (4499 events)
#                          : Elapsed time for evaluation of 4499 events: 0.402 sec
# Factory                  : Evaluate all methods
# Factory                  : Evaluate classifier: Fisher
#                          :
# TFHandler_Fisher         :                 Variable                        Mean                        RMS                [        Min                        Max ]
#                          : -------------------------------------------------------------------------------------------------------------------------------------------
#                          :                lepton_pT:                 -0.028041                    1.0212   [                   -3.4707                    6.0865 ]
#                          :               lepton_eta:                  0.044963                    1.0351   [                   -3.0754                    6.2123 ]
#                          :               lepton_phi:                  0.019622                    1.0009   [                   -3.1824                    5.8592 ]
#                          : missing_energy_magnitude:                  0.071349                    1.0191   [                   -3.2320                    6.2002 ]
#                          :       missing_energy_phi:                -0.0056423                    1.0105   [                   -3.0336                    5.8556 ]
#                          :                 jet_1_pt:                   0.11591                   0.99722   [                   -3.0736                    3.6321 ]
#                          :                jet_1_eta:                  0.018726                    1.0282   [                   -3.6074                    6.3038 ]
#                          :                jet_1_phi:                  0.052698                   0.99252   [                   -3.0902                    5.8986 ]
#                          :              jet_1_b_tag:                    1.0625                   0.99271   [                  -0.48994                    2.7091 ]
#                          :                 jet_2_pt:                  0.099808                    1.0010   [                   -3.3577                    5.5914 ]
#                          :                jet_2_eta:                  0.010092                    1.0359   [                   -3.3372                    6.3882 ]
#                          :                jet_2_phi:                 -0.026093                   0.99896   [                   -3.0064                    5.7974 ]
#                          :              jet_2_b_tag:                    1.0408                    1.0049   [                  -0.45802                    2.6325 ]
#                          :                 jet_3_pt:                   0.14906                   0.97222   [                   -3.1355                    3.2735 ]
#                          :                jet_3_eta:                  0.031054                   0.98971   [                   -3.1735                    5.8697 ]
#                          :                jet_3_phi:               -0.00028228                   0.99432   [                   -3.0859                    5.8534 ]
#                          :              jet_3_b_tag:                   0.96451                    1.0100   [                  -0.51662                    2.6065 ]
#                          :                 jet_4_pt:                   0.17296                    1.0127   [                   -3.2279                    6.1930 ]
#                          :                jet_4_eta:                  0.026002                    1.0127   [                   -3.0038                    5.8948 ]
#                          :                jet_4_phi:                -0.0090620                   0.98370   [                   -2.9508                    5.8320 ]
#                          :              jet_4_b_tag:                   0.81683                   0.99228   [                  -0.58758                    2.6439 ]
#                          :                     m_jj:                  0.089290                    1.0073   [                   -3.2839                    4.2455 ]
#                          :                    m_jjj:                  -0.11765                   0.98945   [                   -3.4205                    5.7563 ]
#                          :                     m_lv:                  0.038445                    1.0053   [                   -3.1692                    5.5002 ]
#                          :                    m_jlv:                  -0.12574                   0.99888   [                   -7.0610                    5.5834 ]
#                          :                     m_bb:                  -0.25433                   0.98148   [                   -3.7342                    4.6681 ]
#                          :                    m_wbb:                  -0.11687                    1.0144   [                   -4.7679                    7.0438 ]
#                          :                   m_wwbb:                  0.030796                    1.0410   [                   -7.9222                    9.1578 ]
#                          : -------------------------------------------------------------------------------------------------------------------------------------------
# Fisher                   : [dataset] : Loop over test events and fill histograms with classifier response...
#                          :
# TFHandler_Fisher         :                 Variable                        Mean                        RMS                [        Min                        Max ]
#                          : -------------------------------------------------------------------------------------------------------------------------------------------
#                          :                lepton_pT:                 -0.028041                    1.0212   [                   -3.4707                    6.0865 ]
#                          :               lepton_eta:                  0.044963                    1.0351   [                   -3.0754                    6.2123 ]
#                          :               lepton_phi:                  0.019622                    1.0009   [                   -3.1824                    5.8592 ]
#                          : missing_energy_magnitude:                  0.071349                    1.0191   [                   -3.2320                    6.2002 ]
#                          :       missing_energy_phi:                -0.0056423                    1.0105   [                   -3.0336                    5.8556 ]
#                          :                 jet_1_pt:                   0.11591                   0.99722   [                   -3.0736                    3.6321 ]
#                          :                jet_1_eta:                  0.018726                    1.0282   [                   -3.6074                    6.3038 ]
#                          :                jet_1_phi:                  0.052698                   0.99252   [                   -3.0902                    5.8986 ]
#                          :              jet_1_b_tag:                    1.0625                   0.99271   [                  -0.48994                    2.7091 ]
#                          :                 jet_2_pt:                  0.099808                    1.0010   [                   -3.3577                    5.5914 ]
#                          :                jet_2_eta:                  0.010092                    1.0359   [                   -3.3372                    6.3882 ]
#                          :                jet_2_phi:                 -0.026093                   0.99896   [                   -3.0064                    5.7974 ]
#                          :              jet_2_b_tag:                    1.0408                    1.0049   [                  -0.45802                    2.6325 ]
#                          :                 jet_3_pt:                   0.14906                   0.97222   [                   -3.1355                    3.2735 ]
#                          :                jet_3_eta:                  0.031054                   0.98971   [                   -3.1735                    5.8697 ]
#                          :                jet_3_phi:               -0.00028228                   0.99432   [                   -3.0859                    5.8534 ]
#                          :              jet_3_b_tag:                   0.96451                    1.0100   [                  -0.51662                    2.6065 ]
#                          :                 jet_4_pt:                   0.17296                    1.0127   [                   -3.2279                    6.1930 ]
#                          :                jet_4_eta:                  0.026002                    1.0127   [                   -3.0038                    5.8948 ]
#                          :                jet_4_phi:                -0.0090620                   0.98370   [                   -2.9508                    5.8320 ]
#                          :              jet_4_b_tag:                   0.81683                   0.99228   [                  -0.58758                    2.6439 ]
#                          :                     m_jj:                  0.089290                    1.0073   [                   -3.2839                    4.2455 ]
#                          :                    m_jjj:                  -0.11765                   0.98945   [                   -3.4205                    5.7563 ]
#                          :                     m_lv:                  0.038445                    1.0053   [                   -3.1692                    5.5002 ]
#                          :                    m_jlv:                  -0.12574                   0.99888   [                   -7.0610                    5.5834 ]
#                          :                     m_bb:                  -0.25433                   0.98148   [                   -3.7342                    4.6681 ]
#                          :                    m_wbb:                  -0.11687                    1.0144   [                   -4.7679                    7.0438 ]
#                          :                   m_wwbb:                  0.030796                    1.0410   [                   -7.9222                    9.1578 ]
#                          : -------------------------------------------------------------------------------------------------------------------------------------------
#                          :
#                          : <PlotVariables> Will not produce scatter plots ==>
#                          : |  The number of 28 input variables and 0 target values would require 378 two-dimensional
#                          : |  histograms, which would occupy the computer's memory. Note that this
#                          : |  suppression does not have any consequences for your analysis, other
#                          : |  than not disposing of these scatter plots. You can modify the maximum
#                          : |  number of input variables allowed to generate scatter plots in your
#                          : |  script via the command line:
#                          : |  "(TMVA::gConfig().GetVariablePlotting()).fMaxNumOfAllowedVariablesForScatterPlots = <some int>;"
#                          :
#                          : Some more output
# Factory                  : Evaluate classifier: BDT
#                          :
# TFHandler_BDT            :                 Variable                        Mean                        RMS                [        Min                        Max ]
#                          : -------------------------------------------------------------------------------------------------------------------------------------------
#                          :                lepton_pT:                 -0.028041                    1.0212   [                   -3.4707                    6.0865 ]
#                          :               lepton_eta:                  0.044963                    1.0351   [                   -3.0754                    6.2123 ]
#                          :               lepton_phi:                  0.019622                    1.0009   [                   -3.1824                    5.8592 ]
#                          : missing_energy_magnitude:                  0.071349                    1.0191   [                   -3.2320                    6.2002 ]
#                          :       missing_energy_phi:                -0.0056423                    1.0105   [                   -3.0336                    5.8556 ]
#                          :                 jet_1_pt:                   0.11591                   0.99722   [                   -3.0736                    3.6321 ]
#                          :                jet_1_eta:                  0.018726                    1.0282   [                   -3.6074                    6.3038 ]
#                          :                jet_1_phi:                  0.052698                   0.99252   [                   -3.0902                    5.8986 ]
#                          :              jet_1_b_tag:                    1.0625                   0.99271   [                  -0.48994                    2.7091 ]
#                          :                 jet_2_pt:                  0.099808                    1.0010   [                   -3.3577                    5.5914 ]
#                          :                jet_2_eta:                  0.010092                    1.0359   [                   -3.3372                    6.3882 ]
#                          :                jet_2_phi:                 -0.026093                   0.99896   [                   -3.0064                    5.7974 ]
#                          :              jet_2_b_tag:                    1.0408                    1.0049   [                  -0.45802                    2.6325 ]
#                          :                 jet_3_pt:                   0.14906                   0.97222   [                   -3.1355                    3.2735 ]
#                          :                jet_3_eta:                  0.031054                   0.98971   [                   -3.1735                    5.8697 ]
#                          :                jet_3_phi:               -0.00028228                   0.99432   [                   -3.0859                    5.8534 ]
#                          :              jet_3_b_tag:                   0.96451                    1.0100   [                  -0.51662                    2.6065 ]
#                          :                 jet_4_pt:                   0.17296                    1.0127   [                   -3.2279                    6.1930 ]
#                          :                jet_4_eta:                  0.026002                    1.0127   [                   -3.0038                    5.8948 ]
#                          :                jet_4_phi:                -0.0090620                   0.98370   [                   -2.9508                    5.8320 ]
#                          :              jet_4_b_tag:                   0.81683                   0.99228   [                  -0.58758                    2.6439 ]
#                          :                     m_jj:                  0.089290                    1.0073   [                   -3.2839                    4.2455 ]
#                          :                    m_jjj:                  -0.11765                   0.98945   [                   -3.4205                    5.7563 ]
#                          :                     m_lv:                  0.038445                    1.0053   [                   -3.1692                    5.5002 ]
#                          :                    m_jlv:                  -0.12574                   0.99888   [                   -7.0610                    5.5834 ]
#                          :                     m_bb:                  -0.25433                   0.98148   [                   -3.7342                    4.6681 ]
#                          :                    m_wbb:                  -0.11687                    1.0144   [                   -4.7679                    7.0438 ]
#                          :                   m_wwbb:                  0.030796                    1.0410   [                   -7.9222                    9.1578 ]
#                          : -------------------------------------------------------------------------------------------------------------------------------------------
# BDT                      : [dataset] : Loop over test events and fill histograms with classifier response...
#                          :
# TFHandler_BDT            :                 Variable                        Mean                        RMS                [        Min                        Max ]
#                          : -------------------------------------------------------------------------------------------------------------------------------------------
#                          :                lepton_pT:                 -0.028041                    1.0212   [                   -3.4707                    6.0865 ]
#                          :               lepton_eta:                  0.044963                    1.0351   [                   -3.0754                    6.2123 ]
#                          :               lepton_phi:                  0.019622                    1.0009   [                   -3.1824                    5.8592 ]
#                          : missing_energy_magnitude:                  0.071349                    1.0191   [                   -3.2320                    6.2002 ]
#                          :       missing_energy_phi:                -0.0056423                    1.0105   [                   -3.0336                    5.8556 ]
#                          :                 jet_1_pt:                   0.11591                   0.99722   [                   -3.0736                    3.6321 ]
#                          :                jet_1_eta:                  0.018726                    1.0282   [                   -3.6074                    6.3038 ]
#                          :                jet_1_phi:                  0.052698                   0.99252   [                   -3.0902                    5.8986 ]
#                          :              jet_1_b_tag:                    1.0625                   0.99271   [                  -0.48994                    2.7091 ]
#                          :                 jet_2_pt:                  0.099808                    1.0010   [                   -3.3577                    5.5914 ]
#                          :                jet_2_eta:                  0.010092                    1.0359   [                   -3.3372                    6.3882 ]
#                          :                jet_2_phi:                 -0.026093                   0.99896   [                   -3.0064                    5.7974 ]
#                          :              jet_2_b_tag:                    1.0408                    1.0049   [                  -0.45802                    2.6325 ]
#                          :                 jet_3_pt:                   0.14906                   0.97222   [                   -3.1355                    3.2735 ]
#                          :                jet_3_eta:                  0.031054                   0.98971   [                   -3.1735                    5.8697 ]
#                          :                jet_3_phi:               -0.00028228                   0.99432   [                   -3.0859                    5.8534 ]
#                          :              jet_3_b_tag:                   0.96451                    1.0100   [                  -0.51662                    2.6065 ]
#                          :                 jet_4_pt:                   0.17296                    1.0127   [                   -3.2279                    6.1930 ]
#                          :                jet_4_eta:                  0.026002                    1.0127   [                   -3.0038                    5.8948 ]
#                          :                jet_4_phi:                -0.0090620                   0.98370   [                   -2.9508                    5.8320 ]
#                          :              jet_4_b_tag:                   0.81683                   0.99228   [                  -0.58758                    2.6439 ]
#                          :                     m_jj:                  0.089290                    1.0073   [                   -3.2839                    4.2455 ]
#                          :                    m_jjj:                  -0.11765                   0.98945   [                   -3.4205                    5.7563 ]
#                          :                     m_lv:                  0.038445                    1.0053   [                   -3.1692                    5.5002 ]
#                          :                    m_jlv:                  -0.12574                   0.99888   [                   -7.0610                    5.5834 ]
#                          :                     m_bb:                  -0.25433                   0.98148   [                   -3.7342                    4.6681 ]
#                          :                    m_wbb:                  -0.11687                    1.0144   [                   -4.7679                    7.0438 ]
#                          :                   m_wwbb:                  0.030796                    1.0410   [                   -7.9222                    9.1578 ]
#                          : -------------------------------------------------------------------------------------------------------------------------------------------
#                          :
#                          : <PlotVariables> Will not produce scatter plots ==>
#                          : |  The number of 28 input variables and 0 target values would require 378 two-dimensional
#                          : |  histograms, which would occupy the computer's memory. Note that this
#                          : |  suppression does not have any consequences for your analysis, other
#                          : |  than not disposing of these scatter plots. You can modify the maximum
#                          : |  number of input variables allowed to generate scatter plots in your
#                          : |  script via the command line:
#                          : |  "(TMVA::gConfig().GetVariablePlotting()).fMaxNumOfAllowedVariablesForScatterPlots = <some int>;"
#                          :
#                          : Some more output
#                          :
#                          : Evaluation results ranked by best signal efficiency and purity (area)
#                          : -------------------------------------------------------------------------------------------------------------------
#                          : DataSet       MVA
#                          : Name:         Method:          ROC-integ
#                          : dataset       BDT            : 0.753
#                          : dataset       Fisher         : 0.674
#                          : -------------------------------------------------------------------------------------------------------------------
#                          :
#                          : Testing efficiency compared to training efficiency (overtraining check)
#                          : -------------------------------------------------------------------------------------------------------------------
#                          : DataSet              MVA              Signal efficiency: from test sample (from training sample)
#                          : Name:                Method:          @B=0.01             @B=0.10            @B=0.30
#                          : -------------------------------------------------------------------------------------------------------------------
#                          : dataset              BDT            : 0.072 (0.508)       0.369 (0.700)      0.664 (0.835)
#                          : dataset              Fisher         : 0.023 (0.026)       0.188 (0.213)      0.564 (0.560)
#                          : -------------------------------------------------------------------------------------------------------------------
#                          :
# Dataset:dataset          : Created tree 'TestTree' with 4499 events
#                          :
# Dataset:dataset          : Created tree 'TrainTree' with 5500 events
#                          :
# Factory                  : Thank you for using TMVA!
#                          : For citation information, please visit: http://tmva.sf.net/citeTMVA.html
# 0%, time left: unknown
# 7%, time left: 0 sec
# 13%, time left: 0 sec
# 19%, time left: 0 sec
# 25%, time left: 0 sec
# 32%, time left: 0 sec
# 38%, time left: 0 sec
# 44%, time left: 0 sec
# 50%, time left: 0 sec
# 57%, time left: 0 sec
# 63%, time left: 0 sec
# 69%, time left: 0 sec
# 75%, time left: 0 sec
# 82%, time left: 0 sec
# 88%, time left: 0 sec
# 94%, time left: 0 sec
# 0%, time left: unknown
# 6%, time left: 4 sec
# 12%, time left: 3 sec
# 18%, time left: 3 sec
# 25%, time left: 3 sec
# 31%, time left: 3 sec
# 37%, time left: 2 sec
# 43%, time left: 2 sec
# 50%, time left: 2 sec
# 56%, time left: 2 sec
# 62%, time left: 1 sec
# 68%, time left: 1 sec
# 75%, time left: 1 sec
# 81%, time left: 0 sec
# 87%, time left: 0 sec
# 93%, time left: 0 sec
# 0%, time left: unknown
# 7%, time left: 0 sec
# 13%, time left: 0 sec
# 19%, time left: 0 sec
# 25%, time left: 0 sec
# 32%, time left: 0 sec
# 38%, time left: 0 sec
# 44%, time left: 0 sec
# 50%, time left: 0 sec
# 57%, time left: 0 sec
# 63%, time left: 0 sec
# 69%, time left: 0 sec
# 75%, time left: 0 sec
# 82%, time left: 0 sec
# 88%, time left: 0 sec
# 94%, time left: 0 sec
# 0%, time left: unknown
# 6%, time left: 0 sec
# 12%, time left: 0 sec
# 19%, time left: 0 sec
# 25%, time left: 0 sec
# 31%, time left: 0 sec
# 38%, time left: 0 sec
# 44%, time left: 0 sec
# 50%, time left: 0 sec
# 56%, time left: 0 sec
# 62%, time left: 0 sec
# 69%, time left: 0 sec
# 75%, time left: 0 sec
# 82%, time left: 0 sec
# 88%, time left: 0 sec
# 93%, time left: 0 sec
# 0%, time left: unknown
# 6%, time left: 0 sec
# 12%, time left: 0 sec
# 19%, time left: 0 sec
# 25%, time left: 0 sec
# 31%, time left: 0 sec
# 38%, time left: 0 sec
# 44%, time left: 0 sec
# 50%, time left: 0 sec
# 56%, time left: 0 sec
# 62%, time left: 0 sec
# 69%, time left: 0 sec
# 75%, time left: 0 sec
# 82%, time left: 0 sec
# 88%, time left: 0 sec
# 93%, time left: 0 sec

# %% [markdown]
# Now the `TMVA.root` will contain all the usefull information of the analysis. In order to save all the plots, start a root session in a terminal and run `TMVA::TMVAGui("TMVA.root")`.
